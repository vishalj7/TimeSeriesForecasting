# %%
# Testing

# %%
# Libraries

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import statsmodels as sm

from tsf.SARIMA_tsf import SARIMA_tsf

# %%
#Load Data

file = "data/norway_new_car_sales_by_month.csv"
df = pd.read_csv(file, sep=',', header=0)

# %%
df.head()
# Out:
#    Year  Month  Quantity  Quantity_YoY  Import  Import_YoY  Used  Used_YoY  \
# 0  2007      1     12685          5227    2276         257   NaN       NaN
# 1  2007      2      9793          2448    1992         -89   NaN       NaN
# 2  2007      3     11264          1445    2626          45   NaN       NaN
# 3  2007      4      8854           504    2220        -130   NaN       NaN
# 4  2007      5     12007          1592    2881           7   NaN       NaN
#
#    Avg_CO2  Bensin_Co2  Diesel_Co2  Quantity_Diesel  Diesel_Share  \
# 0      152         155         152            10072          79.4
# 1      156         159         155             7222          73.7
# 2      159         161         158             7965          70.7
# 3      160         165         158             6116          69.1
# 4      160         163         159             8519          71.0
#
#    Diesel_Share_LY  Quantity_Hybrid  Quantity_Electric  Import_Electric
# 0             52.5              NaN                NaN              NaN
# 1             47.4              NaN                NaN              NaN
# 2             48.1              NaN                NaN              NaN
# 3             48.4              NaN                NaN              NaN
# 4             49.1              NaN                NaN              NaN

# %%
# Replace any NaN values with 0 and create additional features
df = df.fillna(0)
df['Day'] = '1'
df['Date'] = pd.to_datetime(df[['Year','Month', 'Day']], format = "%y-%m")
df['Quantity_Petrol'] = df['Quantity'] - df['Quantity_Diesel'] - df['Quantity_Hybrid'] - df['Quantity_Electric']                    
df['Non_Import'] = df['Quantity'] - df['Import']

# %%
# Convert Date to a Year_Month format and drop unnecessary features
df['Year_Month'] = df['Date'].dt.to_period('M')
df = df.drop(['Year','Month', 'Day','Diesel_Share_LY', 'Avg_CO2', 'Bensin_Co2', 'Diesel_Co2'], axis = 1)
df.head()
# Out:
#    Quantity  Quantity_YoY  Import  Import_YoY  Used  Used_YoY  \
# 0     12685          5227    2276         257   0.0       0.0
# 1      9793          2448    1992         -89   0.0       0.0
# 2     11264          1445    2626          45   0.0       0.0
# 3      8854           504    2220        -130   0.0       0.0
# 4     12007          1592    2881           7   0.0       0.0
#
#    Quantity_Diesel  Diesel_Share  Quantity_Hybrid  Quantity_Electric  \
# 0            10072          79.4              0.0                0.0
# 1             7222          73.7              0.0                0.0
# 2             7965          70.7              0.0                0.0
# 3             6116          69.1              0.0                0.0
# 4             8519          71.0              0.0                0.0
#
#    Import_Electric       Date  Quantity_Petrol  Non_Import Year_Month
# 0              0.0 2007-01-01           2613.0       10409    2007-01
# 1              0.0 2007-02-01           2571.0        7801    2007-02
# 2              0.0 2007-03-01           3299.0        8638    2007-03
# 3              0.0 2007-04-01           2738.0        6634    2007-04
# 4              0.0 2007-05-01           3488.0        9126    2007-05

# %%
# Split the data into test and train and then calculate the sum of Quantity for each Year_Month value
df_sales = df.drop(['Date'], axis=1)
df_sales = df_sales.groupby(['Year_Month'])['Quantity'].sum().to_frame()
df_sales.index = df_sales.index.to_timestamp()
print(df_sales.head())
# Out:
#             Quantity
# Year_Month
# 2007-01-01     12685
# 2007-02-01      9793
# 2007-03-01     11264
# 2007-04-01      8854
# 2007-05-01     12007

# %%
# Split the data into test and train and then calculate the sum of Quantity for each Year_Month value
df_days = df.drop(['Year_Month'], axis=1)
df_days = df_days.groupby(['Date'])['Quantity'].sum().to_frame()
print(df_days.head())
# Out:
#             Quantity
# Date
# 2007-01-01     12685
# 2007-02-01      9793
# 2007-03-01     11264
# 2007-04-01      8854
# 2007-05-01     12007

# %%
x = df_sales.reset_index()['Year_Month']
x
# Out:
# 0     2007-01-01
# 1     2007-02-01
# 2     2007-03-01
# 3     2007-04-01
# 4     2007-05-01
#          ...
# 116   2016-09-01
# 117   2016-10-01
# 118   2016-11-01
# 119   2016-12-01
# 120   2017-01-01
# Name: Year_Month, Length: 121, dtype: datetime64[ns]

# %%
# Plots the training data
df_sales_fig = df_sales.plot(figsize=(20,10), title="Total Sales In Norway January 2007 To January 2017")
plt.xlabel('Date')
plt.ylabel('Total Sales')
plt.show()

# %%
# Functions testing

# %%
tsf = SARIMA_tsf()

# %%
d = tsf.display_rolling_plot(df_sales, 3)
# Out:
# Displaying rolling plot...

# %%
dickey_test = tsf.dickey_fuller_test(df_sales)
dickey_test
# Out:
# Test Statistic                  -0.972475
# p-value                          0.763171
# #Lags Used                       6.000000
# Number of Observations Used    114.000000
# Critical Value (1%)             -3.489058
# Critical Value (5%)             -2.887246
# Critical Value (10%)            -2.580481
# dtype: float64

# %%
decompose, decom_fig = tsf.decompose(df_sales, 'additive')

# %%
grid_cv_df = tsf.grid_search_CV(df_sales, range(0,2), [12], {'months': -12}, {'months': 6})
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /opt/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)

# %%
grid_cv_df
# Out:
#    order_param seasonal_order_param mape_total mape_months
# 0    (0, 0, 0)        (0, 0, 0, 12)      100.0       100.0
# 1    (0, 0, 0)        (0, 0, 1, 12)      64.33       64.48
# 2    (0, 0, 0)        (0, 1, 0, 12)       6.09        6.77
# 3    (0, 0, 0)        (0, 1, 1, 12)       6.62        6.79
# 4    (0, 0, 0)        (1, 0, 0, 12)       5.77        6.55
# ..         ...                  ...        ...         ...
# 59   (1, 1, 1)        (0, 1, 1, 12)       3.19        5.22
# 60   (1, 1, 1)        (1, 0, 0, 12)        3.7        5.75
# 61   (1, 1, 1)        (1, 0, 1, 12)        3.7        5.72
# 62   (1, 1, 1)        (1, 1, 0, 12)       3.87        5.81
# 63   (1, 1, 1)        (1, 1, 1, 12)       3.18        5.19
#
# [64 rows x 4 columns]

# %%
aic_scores = tsf.grid_search_run(df_sales, range(0,2), [6, 12])

# %%
# If grid_search_CV is used this method doesn't need to be run
model_run_validation = tsf.run_model_validation(aic_scores, df_sales, {'months': -12}, {'months': 6})
model_run_validation
# Out:
#   order_param seasonal_order_param mape_total mape_months
# 0   (1, 1, 1)        (0, 1, 1, 12)       3.19        5.22
# 1   (1, 1, 1)        (1, 1, 1, 12)       3.18        5.19
# 2   (0, 1, 1)        (0, 1, 1, 12)       3.05         5.1
# 3   (0, 1, 1)        (1, 1, 1, 12)       3.05        5.09
# 4   (1, 0, 1)        (0, 1, 1, 12)       3.58        5.28

# %%
forecast_res = tsf.plot_actuals_vs_forecast(df_sales, (1, 1, 1), (0, 1, 1, 12), 12, \
                        "fake", '2016-06-01', '2015-01-01', "Year-Month", 0.05)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-0241b08cd466> in <module>
# ----> 1 forecast_res = tsf.plot_actuals_vs_forecast(df_sales, (1, 1, 1), (0, 1, 1, 12), 12, \
#       2                         "fake", '2016-06-01', '2015-01-01', "Year-Month", 0.05)
#
# AttributeError: 'SARIMA_tsf' object has no attribute 'plot_actuals_vs_forecast'

# %%
res_model_build = tsf.model_build(df_sales, (1, 1, 1), (1, 1, 0, 12))

# %%
print("Summary Results Table.") 
print(res_model_build.summary().tables[1])
# Out:
# Summary Results Table.
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.3616      0.130     -2.791      0.005      -0.616      -0.108
# ma.L1         -0.4941      0.108     -4.590      0.000      -0.705      -0.283
# ar.S.L12      -0.4332      0.092     -4.705      0.000      -0.614      -0.253
# sigma2      1.233e+06   1.76e+05      7.009      0.000    8.88e+05    1.58e+06
# ==============================================================================

# %%
f_vs_a = tsf.plot_forecasts(res_model_build, 12, df_sales, "made up", '2014-01-01')

# %%
tsf.result_evaluation(model_run_validation)
